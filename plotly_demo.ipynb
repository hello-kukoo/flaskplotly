# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from plotly import tools
import plotly_express as px

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

import numpy as np
import pandas as pd
import urllib
import json

# %%
import app

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
x = np.random.randn(2000)
y = np.random.randn(2000)
iplot([go.Histogram2dContour(x=x, y=y, contours=dict(coloring='heatmap')),
       go.Scatter(x=x, y=y, mode='markers', marker=dict(color='white', size=3, opacity=0.3))], show_link=False)
# Out:
# <div>
#
#
#             <div id="4125c911-662c-496a-9743-556897d33a28" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4125c911-662c-496a-9743-556897d33a28")) {
#                     Plotly.newPlot(
#                         '4125c911-662c-496a-9743-556897d33a28',
# ...

# %%
data, layout = app.create_surface()

# %%
fig = go.Figure(data=data, layout=layout)
iplot(fig) # iplot({'data':figure, 'layout':layout})
# Out:
# <div>
#
#
#             <div id="bc57e75e-7a0b-482d-9061-4ed5b4c24fde" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bc57e75e-7a0b-482d-9061-4ed5b4c24fde")) {
#                     Plotly.newPlot(
#                         'bc57e75e-7a0b-482d-9061-4ed5b4c24fde',
# ...

# %%
data = app.create_line()

# %%
iplot(data)
# Out:
# <div>
#
#
#             <div id="04fe90f6-a706-46f4-9fa1-225566b232cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("04fe90f6-a706-46f4-9fa1-225566b232cc")) {
#                     Plotly.newPlot(
#                         '04fe90f6-a706-46f4-9fa1-225566b232cc',
# ...

# %%
data = app.create_multiLine()
layout = go.Layout(title='Multi Lines', 
            legend=dict(
                x=0,
                y=1,
                traceorder='normal',
                font=dict(
                    family='sans-serif',
                    size=12,
                    color='#000'
                ),
                bgcolor='#E2E2E2',
                bordercolor='#FFFFFF',
                borderwidth=2,
                orientation="h"
            )
        )
fig = go.Figure(data=data, layout=layout)

# %%
iplot(fig)
# Out:
# <div>
#
#
#             <div id="797c0b5b-931f-4dd0-9a6c-67d825a544c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("797c0b5b-931f-4dd0-9a6c-67d825a544c2")) {
#                     Plotly.newPlot(
#                         '797c0b5b-931f-4dd0-9a6c-67d825a544c2',
# ...

# %%
data, layout = app.create_sankey()
fig = go.Figure(data=data, layout=layout)

# %%
iplot(fig)
# Out:
# <div>
#
#
#             <div id="aa9ba4b8-eb6a-4959-9792-38abf4d21e07" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("aa9ba4b8-eb6a-4959-9792-38abf4d21e07")) {
#                     Plotly.newPlot(
#                         'aa9ba4b8-eb6a-4959-9792-38abf4d21e07',
# ...

# %%
data, layout = app.create_sunburst()
fig = go.Figure(data=data, layout=layout)

# %%
iplot(fig)
# Out:
# <div>
#
#
#             <div id="3f620f3e-e884-4aee-a993-e9b92fb2bada" class="plotly-graph-div" style="height:900px; width:1500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3f620f3e-e884-4aee-a993-e9b92fb2bada")) {
#                     Plotly.newPlot(
#                         '3f620f3e-e884-4aee-a993-e9b92fb2bada',
# ...
